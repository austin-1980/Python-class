# %% [markdown]
# <a href="https://colab.research.google.com/github/austin-1980/Python-class/blob/main/9%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C(2026199444%EC%8B%A0%ED%98%84%EC%A7%81)_20260429142703.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[]
for i in [1,2,3]:
    a.append(i+1)
a
# Out:
# [2, 3, 4]

# %%
[i+1 for i in [1,2,3]]
# Out:
# [2, 3, 4]

# %%
def calcul(i):
    c=i*2*3+i
    return c

# %%
b= [ calcul(i) for i in [1,2,3]]

# %%
b
# Out:
# [7, 14, 21]

# %%
[i+1 for i in[1,2,3] if i%2==0]
# Out:
# [3]

# %%
number_list=[]
number_list.append(1)
number_list.append(2)
number_list.append(3)
number_list.append(4)
number_list.append(5)

# %%
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
[i+1 for i in range(0,5)]
# Out:
# [1, 2, 3, 4, 5]

# %%
number_list=[number for number in range(1,6)]

# %%
number_list
# Out:
# [1, 2, 3, 4, 5]

# %%
sentence = ['I','Love','Python','Soooo','MUCH!!']
[word.lower() for word in sentence]
# Out:
# ['i', 'love', 'python', 'soooo', 'much!!']

# %%
[word for word in sentence if len(word)>4]
# Out:
# ['Python', 'Soooo', 'MUCH!!']

# %%
[(x, x**2,x**3) for x in range(10)]
# Out:
# [(0, 0, 0),
#  (1, 1, 1),
#  (2, 4, 8),
#  (3, 9, 27),
#  (4, 16, 64),
#  (5, 25, 125),
#  (6, 36, 216),
#  (7, 49, 343),
#  (8, 64, 512),
#  (9, 81, 729)]

# %%
rows=range(1,4)
cols=range(1,3)
for row in rows:
    for col in cols:
        print(row,col)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2

# %%
cells=[(row,col) for row in rows for col in cols]
for cell in cells:
    print(cell)
# Out:
# (1, 1)
# (1, 2)
# (2, 1)
# (2, 2)
# (3, 1)
# (3, 2)

# %%
[(i,j) for i in range(5) for j in range(i)]
# Out:
# [(1, 0),
#  (2, 0),
#  (2, 1),
#  (3, 0),
#  (3, 1),
#  (3, 2),
#  (4, 0),
#  (4, 1),
#  (4, 2),
#  (4, 3)]

# %%
word='letters'
letter_counts={letter:word.count(letter) for letter in word}

# %%
letter_counts
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %%
letter_counts={letter:word.count(letter) for letter in set(word)}
letter_counts
# Out:
# {'t': 2, 's': 1, 'e': 2, 'r': 1, 'l': 1}

# %%
a_set={number for number in range(1,6) if number%3==1}

# %%
a_set
# Out:
# {1, 4}

# %%
def sum(a,b):
    return a+b

# %%
sum(1,5)
# Out:
# 6

# %%
sum('I',' love')
# Out:
# 'I love'

# %%
days=['Monday','Tuesday','Wendnesday']
fruits=['banana','orange','peach']
drinks = ['coffee', 'tea', 'beer']
desserts = ['tiramisu', 'ice cream', 'pie', 'pudding']

for day, fruit, drink, dessert in zip(days, fruits, drinks, desserts):
    print(day, ": drink", drink, "- eat", fruit, "- enjoy", dessert)
# Out:
# Monday : drink coffee - eat banana - enjoy tiramisu
# Tuesday : drink tea - eat orange - enjoy ice cream
# Wendnesday : drink beer - eat peach - enjoy pie

# %%
english = 'Monday', 'Tuesday', 'Wednesday'
french = 'Lundi', 'Mardi', 'Mercredi'
list( zip(english, french) )
# [('Monday', 'Lundi'), ('Tuesday', 'Mardi'), ('Wednesday', 'Mercredi')]
dict( zip(english, french) )
# {'Monday': 'Lundi', 'Tuesday': 'Mardi', 'Wednesday': 'Mercredi'}
# Out:
# {'Monday': 'Lundi', 'Tuesday': 'Mardi', 'Wednesday': 'Mercredi'}

# %%
english
# Out:
# ('Monday', 'Tuesday', 'Wednesday')

# %%
def menu(wine, entree, dessert):
    return{'wine':wine, 'entree':entree, 'dessert':dessert}

# %%
menu('Chardonnay','chicken','cake')
# Out:
# {'wine': 'Chardonnay', 'entree': 'chicken', 'dessert': 'cake'}

# %%
menu(entree='beef', dessert='bagel', wine='bordeaux')
# Out:
# {'wine': 'bordeaux', 'entree': 'beef', 'dessert': 'bagel'}

# %%
def menu(wine, entree, dessert='pudding'):
    return {'wine': wine, 'entree': entree, 'dessert': dessert}

# %%
menu ('chardonnay', 'chicken')
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}

# %%
def menu (price,wine='cchardonnay',entree='chicken',dessert='pudding'):
         return {'price': price, 'wine': wine, 'entree': entree, 'dessert': dessert  }

# %%
menu(100)
# Out:
# {'price': 100,
#  'wine': 'cchardonnay',
#  'entree': 'chicken',
#  'dessert': 'pudding'}

# %%
menu (price=100, entree='beef')
# Out:
# {'price': 100, 'wine': 'cchardonnay', 'entree': 'beef', 'dessert': 'pudding'}

# %%
def echo(anything):
    return anything

# %%
echo(1)
# Out:
# 1

# %%
help(echo)
# Out:
# Help on function echo in module __main__:
#
# echo(anything)

# %%
def print_if_true(thing, check):
    if check:
        print(thing)

# %%
print_if_true('hahaha',True)
# Out:
# hahaha

# %%
help(print_if_true)
# Out:
# Help on function print_if_true in module __main__:
#
# print_if_true(thing, check)

# %% [markdown]
# <a href="https://colab.research.google.com/github/austin-1980/Python-class/blob/main/13%EC%A3%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import xml.etree.ElementTree as et
tree = et.ElementTree(file='/content/drive/MyDrive/menu.xml')
root = tree.getroot()

print(root.tag)
# Out:
# menu

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# After running the cell above and following the instructions to mount your Google Drive, please tell me the path to your `menu.xml` file within your Google Drive (e.g., `/content/drive/MyDrive/path/to/menu.xml`).

# %%
for child in root:
    print('tag:',child.tag, 'attributes:',child.attrib)
    for grandchild in child:
        print('\ttag:',grandchild.tag, 'attributes:', grandchild.attrib)
# Out:
# tag: breakfast attributes: {'hours': '7-11'}
# 	tag: item attributes: {'price': '$6.00'}
# 	tag: item attributes: {'price': '$4.00'}
# tag: lunch attributes: {'hours': '11-3'}
# 	tag: item attributes: {'price': '$5.00'}
# tag: dinner attributes: {'hours': '3-10'}
# 	tag: item attributes: {'price': '8.00'}

# %%
len(root)
# Out:
# 3

# %%
len(root[0])
# Out:
# 2

# %%
print(root[0])
# Out:
# <Element 'breakfast' at 0x7cad704da7a0>

# %%
print(root[0].get('hours'))
# Out:
# 7-11

# %%
print(root[0].keys())
# Out:
# ['hours']

# %%
print(root[0].items)
# Out:
# <built-in method items of xml.etree.ElementTree.Element object at 0x7cad704da7a0>

# %%
lunch=root.find('lunch')
print(lunch)
print(lunch.get('hours'))
print(lunch.keys())
print(lunch.items())
# Out:
# <Element 'lunch' at 0x7cad704dbb50>
# 11-3
# ['hours']
# [('hours', '11-3')]

# %%
print(root[0].findall('item'))
# Out:
# [<Element 'item' at 0x7cad704dbd80>, <Element 'item' at 0x7cad704dbdd0>]

# %%
print(root[0].findall('item'))
for item in root[0].findall('item'):
  print(item.get('price'))
  print(item.text)
# Out:
# [<Element 'item' at 0x7cad704dbd80>, <Element 'item' at 0x7cad704dbdd0>]
# $6.00
# breakfast burritos
# $4.00
# pancakes

# %%
import json
j1={"name":"홍길동", "birth":"0525","age":30}

# %%
j1
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
type(j1)
# Out:
# dict

# %%
json.dumps(j1)
# Out:
# '{"name": "\\ud64d\\uae38\\ub3d9", "birth": "0525", "age": 30}'

# %%
print(json.dumps(j1,indent=2))
# Out:
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0525",
#   "age": 30
# }

# %%
json.dumps([1,2,3])
# Out:
# '[1, 2, 3]'

# %%
d1=json.dumps(j1)

# %%
json.loads(d1)
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
import json


with open('./myinfo.json') as f:
  data = json.load(f)

# %%
from urllib.request import urlopen
from urllib.error import URLError

try:
    html = urlopen("http://pythonscraping.com/pages/page1.html")
    print(html.read())
except URLError as e:
    print(f"An error occurred: {e}")
    print("Please check the URL or your network connection, or try again later.")
# Out:
# An error occurred: <urlopen error [Errno 110] Connection timed out>
# Please check the URL or your network connection, or try again later.

# %%
from urllib.request import urlopen
from urllib.error import URLError

try:
    html = urlopen("http://pythonscraping.com/pages/page1.html")
    print(html.read())
except URLError as e:
    print(f"An error occurred: {e}")
    print("Please check the URL or your network connection, or try again later.")

# %%
from urllib.request import urlopen
from urllib.error import URLError
from bs4 import BeautifulSoup

try:
    html = urlopen("http://pythonscraping.com/pages/page1.html")
    bsObj = BeautifulSoup(html.read(), "html.parser")
    print(bsObj.h1)
except URLError as e:
    print(f"An error occurred while trying to connect: {e}")
    print("Please check the URL or your network connection, or try again later.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# An error occurred while trying to connect: <urlopen error [Errno 110] Connection timed out>
# Please check the URL or your network connection, or try again later.

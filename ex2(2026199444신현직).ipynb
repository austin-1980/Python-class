# %% [markdown]
# <a href="https://colab.research.google.com/github/austin-1980/Python-class/blob/main/ex2(2026199444%EC%8B%A0%ED%98%84%EC%A7%81).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
type(3.0)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
type(-1)
# Out:
# int

# %%
# 두번째 과제 입니다.
# 학번 : 2026199444
# 이름 : 신현직

# %%
import sys
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
type(float(2))
# Out:
# float

# %%
int(2.5)
# Out:
# 2

# %%
type(int('1'))
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

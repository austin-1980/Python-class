# %% [markdown]
# <a href="https://colab.research.google.com/github/austin-1980/Python-class/blob/main/ex1(2026199444%EC%8B%A0%ED%98%84%EC%A7%81).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hello world')
# Out:
# hello world

# %%
# check the Python version
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
# 첫 과제 제출 합니다.
# 학번 : 2026199444
# 이름 : 신현직

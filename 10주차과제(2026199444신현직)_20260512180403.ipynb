# %% [markdown]
# <a href="https://colab.research.google.com/github/austin-1980/Python-class/blob/main/10%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C(2026199444%EC%8B%A0%ED%98%84%EC%A7%81)_20260512180403.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
result=0

# %%
def adder(num):
    global result
    result += num
    return result

# %%
print(adder(3))
# Out:
# 3

# %%
result1=0
result2=0

# %%
def adder1(num):
    global result1
    result1+=num
    return result1

# %%
def adder2(num):
    global result2
    result2+=num
    return result2

# %%
print(adder1(4))
print(adder2(6))
# Out:
# 4
# 6

# %%
class Calculator:
    def __init__(self):
        self.result=0

    def adder(self, num):
        self.result += num
        return self.result

# %%
cal1=Calculator()
cal2=Calculator()

# %%
print(cal1.adder(3))
print(cal2.adder(10))
# Out:
# 3
# 10

# %%
class Service:
    secret="지구는 4006년에 멸망한다"

# %%
an = Service()

# %%
an.secret
# Out:
# '지구는 4006년에 멸망한다'

# %%
cal1.result
# Out:
# 3

# %%
s2=Service()

# %%
s2.secret
# Out:
# '지구는 4006년에 멸망한다'

# %%
Service.secret
# Out:
# '지구는 4006년에 멸망한다'

# %%
Calculator.result
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_34263/137636808.py in <cell line: 0>()
# ----> 1 Calculator.result
#
# AttributeError: type object 'Calculator' has no attribute 'result'

# %%
class Service:
    secret="지구는 4006년에 멸망한다"
    def setname(self,name):
        self.name=name

    def sum(self, a, b):
        result=a+b
        print("%s 님, %s + %s = %s 입니다." %(self.name,a,b,result))

# %%
s=Service()

# %%
s.sum(1,5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_34263/1702190958.py in <cell line: 0>()
# ----> 1 s.sum(1,5)
#
# /tmp/ipykernel_34263/161174713.py in sum(self, a, b)
#       6     def sum(self, a, b):
#       7         result=a+b
# ----> 8         print("%s 님, %s + %s = %s 입니다." %(self.name,a,b,result))
#       9
#
# AttributeError: 'Service' object has no attribute 'name'

# %%
an=Service()

# %%
an.setname('신현직')

# %%
an.sum(5,6)
# Out:
# 신현직 님, 5 + 6 = 11 입니다.

# %%
class Service:
    secret="지구는 4006년에 멸망한다"
    def __init__(self,name):
        self.name=name

    def sum(self, a, b):
        result=a+b
        print("%s 님, %s + %s = %s 입니다." %(self.name,a,b,result))

# %%
lee=Service('이재명')

# %%
lee.sum(7,8)
# Out:
# 이재명 님, 7 + 8 = 15 입니다.

# %%
class FourCal:
    pass

# %%
a=FourCal()

# %%
print(type(a))
# Out:
# <class '__main__.FourCal'>

# %%
class FourCal:
    def setdata(self,first, second):
        self.first=first
        self.second=second
    def sum(self):
        result=self.first+self.second
        return result
    def mul(self):
         result=self.first*self.second
         return result
    def sub(self):
         result=self.first-self.second
         return result
    def div(self):
         result=self.first/self.second
         return result

# %%
a=FourCal()

# %%
a.setdata(5,6)

# %%
a.first
# Out:
# 5

# %%
a.second
# Out:
# 6

# %%
print(a.sum())
# Out:
# 11

# %% [raw]
# print(a.mul())

# %%
print(a.mul())
# Out:
# 30

# %%
print(a.sub())
# Out:
# -1

# %%
print(a.div())
# Out:
# 0.8333333333333334

# %%
import random

player1_dice=[]
player2_dice=[]

for i in range(3):
    player1_dice.append(random.randint(1,6))
    player2_dice.append(random.randint(1,6))

print("Player 1 rolled" + str(player1_dice))
print("Player 2 rolled" + str(player2_dice))

if sum(player1_dice) == sum(player2_dice):
    print("Draw")
elif sum(player1_dice)>sum(player2_dice):
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Player 1 rolled[2, 3, 3]
# Player 2 rolled[5, 3, 1]
# Player 2 wins

# %%
from random import randint

class Player:
    def __init__(self):
        self.dice=[]

    def roll(self):
        self.dice=[]
        for i in range(3):
            self.dice.append(randint(1,6))

    def get_dice(self):
        return self.dice

# %%
player1=Player()
player2=Player()

# %%
player1.roll()

# %%
player2.roll()

# %%
print("Player 1 rolled" + str(player1.get_dice()))
print("Player 2 rolled" + str(player2.get_dice()))
# Out:
# Player 1 rolled[5, 1, 1]
# Player 2 rolled[4, 4, 5]

# %%
if sum(player1_dice) == sum(player2_dice):
    print("Draw")
elif sum(player1_dice)>sum(player2_dice):
    print("Player 1 wins")
else:
    print("Player 2 wins")
# Out:
# Player 2 wins
